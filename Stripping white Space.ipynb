# %%
import pandas as pd

# %%
data = pd.read_csv('artwork_data.csv', low_memory=False)

# %%
data.loc[data.title.str.contains('\$', regex=True)]
# Out:
#            id accession_number             artist artistRole  artistId  \
# 1976    97401          AR00239       Warhol, Andy     artist      2121
# 55120  105290           P79798  Hamilton, Richard     artist      1244
# 55259  114012           P79937        Hine, Lewis     artist      9074
# 56759    5829           T01190  Hamilton, Richard     artist      1244
#
#                                                    title        dateText  \
# 1976                Christ $9.98 (negative and positive)          1985–6
# 55120                                          $he(1958)            1982
# 55259  Robert Paul, 216 Johnson Street, 10 year old n...  date not known
# 56759                                                $he         1958–61
#
#                                                   medium  \
# 1976          Acrylic paint and silkscreen on 2 canvases
# 55120                 Collotype and screenprint on paper
# 55259          Photograph, gelatin silver print on paper
# 56759  Oil paint, cellulose nitrate paint, paper and ...
#
#                                               creditLine  year  \
# 1976   ARTIST ROOMS Acquired jointly with the Nationa...  1985
# 55120                     Presented by Tate Members 2010  1982
# 55259   Purchased with assistance from Donald Moore 2010   NaN
# 56759                                     Purchased 1970  1958
#
#        acquisitionYear                                        dimensions  \
# 1976            2009.0                        support: 510 x 410 x 20 mm
# 55120           2009.0                               image: 384 x 280 mm
# 55259           2011.0                                image: 114 x 92 mm
# 56759           1970.0  support: 1219 x 813 mm frame: 1330 x 944 x 98 mm
#
#       width height  depth units inscription                thumbnailCopyright  \
# 1976    510    410   20.0    mm         NaN                               NaN
# 55120   384    280    NaN    mm         NaN  © The estate of Richard Hamilton
# 55259   114     92    NaN    mm         NaN                               NaN
# 56759  1219    813    NaN    mm         NaN  © The estate of Richard Hamilton
#
#                                             thumbnailUrl  \
# 1976                                                 NaN
# 55120  http://www.tate.org.uk/art/images/work/P/P79/P...
# 55259  http://www.tate.org.uk/art/images/work/P/P79/P...
# 56759  http://www.tate.org.uk/art/images/work/T/T01/T...
#
#                                                      url
# 1976   http://www.tate.org.uk/art/artworks/warhol-chr...
# 55120  http://www.tate.org.uk/art/artworks/hamilton-h...
# 55259  http://www.tate.org.uk/art/artworks/hine-rober...
# 56759  http://www.tate.org.uk/art/artworks/hamilton-h...

# %%
data.title.str.strip()
# Out:
# 0        A Figure Bowing before a Seated Old Man with h...
# 1        Two Drawings of Frightened Figures, Probably f...
# 2        The Preaching of Warning. Verso: An Old Man En...
# 3           Six Drawings of Figures with Outstretched Arms
# 4        The Circle of the Lustful: Francesca da Rimini...
#                                ...
# 69196                          Larvae (from Tampax Romana)
# 69197                     Living Womb (from Tampax Romana)
# 69198                                        Present Tense
# 69199            Work No. 227: The lights going on and off
# 69200                     Dancing Scene in the West Indies
# Name: title, Length: 69201, dtype: object

# %%
data.loc[data.title.str.contains('\$', regex=True)]
# Out:
#            id accession_number             artist artistRole  artistId  \
# 1976    97401          AR00239       Warhol, Andy     artist      2121
# 55120  105290           P79798  Hamilton, Richard     artist      1244
# 55259  114012           P79937        Hine, Lewis     artist      9074
# 56759    5829           T01190  Hamilton, Richard     artist      1244
#
#                                                    title        dateText  \
# 1976                Christ $9.98 (negative and positive)          1985–6
# 55120                                          $he(1958)            1982
# 55259  Robert Paul, 216 Johnson Street, 10 year old n...  date not known
# 56759                                                $he         1958–61
#
#                                                   medium  \
# 1976          Acrylic paint and silkscreen on 2 canvases
# 55120                 Collotype and screenprint on paper
# 55259          Photograph, gelatin silver print on paper
# 56759  Oil paint, cellulose nitrate paint, paper and ...
#
#                                               creditLine  year  \
# 1976   ARTIST ROOMS Acquired jointly with the Nationa...  1985
# 55120                     Presented by Tate Members 2010  1982
# 55259   Purchased with assistance from Donald Moore 2010   NaN
# 56759                                     Purchased 1970  1958
#
#        acquisitionYear                                        dimensions  \
# 1976            2009.0                        support: 510 x 410 x 20 mm
# 55120           2009.0                               image: 384 x 280 mm
# 55259           2011.0                                image: 114 x 92 mm
# 56759           1970.0  support: 1219 x 813 mm frame: 1330 x 944 x 98 mm
#
#       width height  depth units inscription                thumbnailCopyright  \
# 1976    510    410   20.0    mm         NaN                               NaN
# 55120   384    280    NaN    mm         NaN  © The estate of Richard Hamilton
# 55259   114     92    NaN    mm         NaN                               NaN
# 56759  1219    813    NaN    mm         NaN  © The estate of Richard Hamilton
#
#                                             thumbnailUrl  \
# 1976                                                 NaN
# 55120  http://www.tate.org.uk/art/images/work/P/P79/P...
# 55259  http://www.tate.org.uk/art/images/work/P/P79/P...
# 56759  http://www.tate.org.uk/art/images/work/T/T01/T...
#
#                                                      url
# 1976   http://www.tate.org.uk/art/artworks/warhol-chr...
# 55120  http://www.tate.org.uk/art/artworks/hamilton-h...
# 55259  http://www.tate.org.uk/art/artworks/hine-rober...
# 56759  http://www.tate.org.uk/art/artworks/hamilton-h...

# %%
data.title = data.title.str.strip()

# %%
data.loc[data.title.str.contains('\s$', regex=True)]
# Out:
# Empty DataFrame
# Columns: [id, accession_number, artist, artistRole, artistId, title, dateText, medium, creditLine, year, acquisitionYear, dimensions, width, height, depth, units, inscription, thumbnailCopyright, thumbnailUrl, url]
# Index: []

# %%
data.title.transform(lambda x: x.strip())
# Out:
# 0        A Figure Bowing before a Seated Old Man with h...
# 1        Two Drawings of Frightened Figures, Probably f...
# 2        The Preaching of Warning. Verso: An Old Man En...
# 3           Six Drawings of Figures with Outstretched Arms
# 4        The Circle of the Lustful: Francesca da Rimini...
#                                ...
# 69196                          Larvae (from Tampax Romana)
# 69197                     Living Womb (from Tampax Romana)
# 69198                                        Present Tense
# 69199            Work No. 227: The lights going on and off
# 69200                     Dancing Scene in the West Indies
# Name: title, Length: 69201, dtype: object
